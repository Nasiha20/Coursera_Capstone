# %% [markdown]
# This is the notebook that will be used for the capstone project for the course Applied Data Science Capstone.

# %%
import pandas as pd

# %%
import numpy as np

# %%
print('hello capstone project course!')
# Out:
# hello capstone project course!
